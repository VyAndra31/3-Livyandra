# %% [markdown]
# <a href="https://colab.research.google.com/github/VyAndra31/3-Livyandra/blob/main/test_github.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello BCC")
# Out:
# Hello BCC
